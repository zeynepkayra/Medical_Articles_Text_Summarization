# %% [markdown]
#  # Extractive Summarization - BERT

# %% [markdown]
# ## 1.0 Install Libraries/Packages

# %%
# %pip install -U datasets
# %pip install transformers torch
# %pip install rouge_score
# Out:
# Requirement already satisfied: datasets in c:\users\edmun\anaconda3\lib\site-packages (2.19.1)
# Requirement already satisfied: filelock in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in c:\users\edmun\anaconda3\lib\site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edmun\anaconda3\lib\site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\edmun\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\edmun\anaconda3\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edmun\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edmun\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edmun\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\edmun\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edmun\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edmun\anaconda3\lib\site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\edmun\anaconda3\lib\site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\edmun\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: transformers in c:\users\edmun\anaconda3\lib\site-packages (4.32.1)
# Requirement already satisfied: torch in c:\users\edmun\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: filelock in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\edmun\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\edmun\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\edmun\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\edmun\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\edmun\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\edmun\anaconda3\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\edmun\anaconda3\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\edmun\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: colorama in c:\users\edmun\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\edmun\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\edmun\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\edmun\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edmun\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\edmun\anaconda3\lib\site-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in c:\users\edmun\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Installing collected packages: tbb
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Requirement already satisfied: rouge_score in c:\users\edmun\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: absl-py in c:\users\edmun\anaconda3\lib\site-packages (from rouge_score) (2.1.0)
# Requirement already satisfied: nltk in c:\users\edmun\anaconda3\lib\site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in c:\users\edmun\anaconda3\lib\site-packages (from rouge_score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in c:\users\edmun\anaconda3\lib\site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in c:\users\edmun\anaconda3\lib\site-packages (from nltk->rouge_score) (8.0.4)
# Requirement already satisfied: joblib in c:\users\edmun\anaconda3\lib\site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\edmun\anaconda3\lib\site-packages (from nltk->rouge_score) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\edmun\anaconda3\lib\site-packages (from nltk->rouge_score) (4.65.0)
# Requirement already satisfied: colorama in c:\users\edmun\anaconda3\lib\site-packages (from click->nltk->rouge_score) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import torch
from datasets import load_dataset
from datasets import load_metric
from transformers import BertTokenizer, BertModel
from typing import Dict, Any
import nltk
nltk.download('punkt')
# Out:
# c:\Users\edmun\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\edmun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 2.0 Load Dataset

# %%
# Load test dataset from huggingface
dataset = load_dataset('ccdv/pubmed-summarization', split="test")

# Take only 125 records from specified seed
test_data = dataset.shuffle(seed=42).select(range(125))
test_df = pd.DataFrame(test_data)
# Out:
# c:\Users\edmun\anaconda3\Lib\site-packages\datasets\load.py:1486: FutureWarning: The repository for ccdv/pubmed-summarization contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/ccdv/pubmed-summarization
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %% [markdown]
# ## 3.0 Transformer Based Extractive Summarization

# %%
# Initialize the tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

def summarize(text, model, tokenizer, num_sentences=5):
    # Lower the text and tokenize into sentences
    sentences = nltk.sent_tokenize(text.lower())

    # Tokenize each sentence and prepare for model input
    tokenized_batches = tokenizer(sentences, return_tensors='pt', padding=True, truncation=True, max_length=128, add_special_tokens=True)

    # Process tokenized text through the model
    with torch.no_grad():
        outputs = model(**{key: tokenized_batches[key].to(model.device) for key in tokenized_batches})
        embeddings = outputs.last_hidden_state[:, 0, :]  # Get embeddings for token

    # Calculate norms and sort by scores
    scores = torch.norm(embeddings, dim=1)
    sorted_indices = torch.argsort(scores, descending=True)

    # Select top sentences based on sorted indices
    best_sentences = [sentences[idx] for idx in sorted_indices[:num_sentences]]
    return ' '.join(best_sentences)

test_df['generated_summary'] = test_df['article'].apply(lambda x: summarize(x, model, tokenizer))

# %%
# Export results to excel
test_df.to_excel('Extractive_BERT_summary.xlsx', index = False)

# %% [markdown]
# ## 4.0 Evaluation

# %%
predictions = list(test_df['generated_summary'])
references = list(test_df['abstract'])

# %%
# ROUGE
rouge = load_metric("rouge")
rouge_scores = rouge.compute(predictions=predictions, references=references)
print(rouge_scores)

def simplify_rouge_scores(rouge_scores: Dict[str, Any]) -> str:
    simplified_text = ""
    for key, value in rouge_scores.items():
        # Extract low, mid, and high scores for each ROUGE metric
        low, mid, high = value.low, value.mid, value.high
        simplified_text += f"{key}: Precision ranges from {low.precision:.2%} to {high.precision:.2%}, "
        simplified_text += f"Recall ranges from {low.recall:.2%} to {high.recall:.2%}, "
        simplified_text += f"F1 Score ranges from {low.fmeasure:.2%} to {high.fmeasure:.2%}.\n"

    return simplified_text

print(simplify_rouge_scores(rouge_scores))

print(rouge_scores)
# Out:
# C:\Users\edmun\AppData\Local\Temp\ipykernel_4004\157201210.py:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# c:\Users\edmun\anaconda3\Lib\site-packages\datasets\load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.1/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# {'rouge1': AggregateScore(low=Score(precision=0.3077256845523563, recall=0.275496588450005, fmeasure=0.2717801542760288), mid=Score(precision=0.3295387492713281, recall=0.2986937338328513, fmeasure=0.2877537272856612), high=Score(precision=0.3523107552704317, recall=0.3213309187305278, fmeasure=0.30312962149956213)), 'rouge2': AggregateScore(low=Score(precision=0.07176920207293085, recall=0.06509838733104711, fmeasure=0.06386349778510031), mid=Score(precision=0.08653680914092493, recall=0.0778592337126677, fmeasure=0.0743377849829847), high=Score(precision=0.10648251630214, recall=0.09269887707948012, fmeasure=0.08608877607815905)), 'rougeL': AggregateScore(low=Score(precision=0.16214057863649164, recall=0.1450581176464134, fmeasure=0.14252135548154474), mid=Score(precision=0.17459375243351072, recall=0.1575473129444167, fmeasure=0.15086526734411038), high=Score(precision=0.1897872838034455, recall=0.17128858761062093, fmeasure=0.1589773726333161)), 'rougeLsum': AggregateScore(low=Score(precision=0.2526739918217382, recall=0.22607977594932366, fmeasure=0.22299818380146963), mid=Score(precision=0.2730994251684171, recall=0.2429947771825725, fmeasure=0.23628488389755337), high=Score(precision=0.29480120782126173, recall=0.26381624860510205, fmeasure=0.25044845614235284))}
# rouge1: Precision ranges from 30.77% to 35.23%, Recall ranges from 27.55% to 32.13%, F1 Score ranges from 27.18% to 30.31%.
# rouge2: Precision ranges from 7.18% to 10.65%, Recall ranges from 6.51% to 9.27%, F1 Score ranges from 6.39% to 8.61%.
# rougeL: Precision ranges from 16.21% to 18.98%, Recall ranges from 14.51% to 17.13%, F1 Score ranges from 14.25% to 15.90%.
# rougeLsum: Precision ranges from 25.27% to 29.48%, Recall ranges from 22.61% to 26.38%, F1 Score ranges from 22.30% to 25.04%.
#
# {'rouge1': AggregateScore(low=Score(precision=0.3077256845523563, recall=0.275496588450005, fmeasure=0.2717801542760288), mid=Score(precision=0.3295387492713281, recall=0.2986937338328513, fmeasure=0.2877537272856612), high=Score(precision=0.3523107552704317, recall=0.3213309187305278, fmeasure=0.30312962149956213)), 'rouge2': AggregateScore(low=Score(precision=0.07176920207293085, recall=0.06509838733104711, fmeasure=0.06386349778510031), mid=Score(precision=0.08653680914092493, recall=0.0778592337126677, fmeasure=0.0743377849829847), high=Score(precision=0.10648251630214, recall=0.09269887707948012, fmeasure=0.08608877607815905)), 'rougeL': AggregateScore(low=Score(precision=0.16214057863649164, recall=0.1450581176464134, fmeasure=0.14252135548154474), mid=Score(precision=0.17459375243351072, recall=0.1575473129444167, fmeasure=0.15086526734411038), high=Score(precision=0.1897872838034455, recall=0.17128858761062093, fmeasure=0.1589773726333161)), 'rougeLsum': AggregateScore(low=Score(precision=0.2526739918217382, recall=0.22607977594932366, fmeasure=0.22299818380146963), mid=Score(precision=0.2730994251684171, recall=0.2429947771825725, fmeasure=0.23628488389755337), high=Score(precision=0.29480120782126173, recall=0.26381624860510205, fmeasure=0.25044845614235284))}
